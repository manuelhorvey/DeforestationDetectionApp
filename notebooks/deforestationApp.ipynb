# %%
pip install gradio

# %%
pip install rasterio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 80.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Create a folder (e.g., 'DeforestationApp')
# !mkdir -p /content/drive/MyDrive/DeforestationApp
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir -p /content/drive/MyDrive/DeforestationApp/models
# !cp /content/drive/MyDrive/models/best_model.pth /content/drive/MyDrive/DeforestationApp/models/

# %%
# !mkdir -p /content/drive/MyDrive/DeforestationApp/data
# Upload files manually via Colab file browser

# %%
import logging
import datetime
logging.basicConfig(filename='/content/drive/MyDrive/DeforestationApp/log.txt', level=logging.INFO)
logging.info("App started at %s", datetime.datetime.now())

# %%
# !zip -r DeforestationApp.zip /content/drive/MyDrive/DeforestationApp
from google.colab import files
files.download('DeforestationApp.zip')
# Out:
# updating: content/drive/MyDrive/DeforestationApp/ (stored 0%)
# updating: content/drive/MyDrive/DeforestationApp/app.py (deflated 66%)
# updating: content/drive/MyDrive/DeforestationApp/.ipynb_checkpoints/ (stored 0%)
# updating: content/drive/MyDrive/DeforestationApp/models/ (stored 0%)
# updating: content/drive/MyDrive/DeforestationApp/models/best_model.pth (deflated 7%)
# updating: content/drive/MyDrive/DeforestationApp/requirements.txt (deflated 16%)
# updating: content/drive/MyDrive/DeforestationApp/data/ (stored 0%)
# updating: content/drive/MyDrive/DeforestationApp/README.md (deflated 46%)

# %%
# %run /content/drive/MyDrive/DeforestationApp/app.py
